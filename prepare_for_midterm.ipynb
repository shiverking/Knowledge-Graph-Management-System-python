# %% [markdown]
# ### 导入“装备知识图谱”与“十一打击群”

# %% [markdown]
# 以下是两个辅助函数，用来存取和读取pkl文件

# %%
import pickle
def save_as_pickle(a_list_or_dict, save_name):
    '''保存数据结构为pkl文件'''
    save_file = open(save_name + '.pkl', 'wb')
    pickle.dump(a_list_or_dict, save_file)
    save_file.close()

def load_pickle_file(file_path):
    '''加载pkl文件'''
    a_list_or_dict = open(file_path, 'rb')
    return pickle.load(a_list_or_dict)

# %% [markdown]
# #### 1 连接图数据库
# 每次也可以通过这个模块来清空数据库

# %%
from py2neo import Graph, Node, Relationship, Graph, NodeMatcher, RelationshipMatcher
graph = Graph('http://localhost:7474', auth=('neo4j', 'Sicdp2021cjw'))
all_node_type = 'ontology_node' # 本体结点类型
graph.delete_all() # 清空图数据库

# %% [markdown]
# #### 2 构建“十一打击群”概念图谱-图结构
# 本体中具有“图结构”和“树结构”，这里“十一打击群”的本体图结构是从“五元组”数据中抽取而来。除此之外我们手动添加了两条规则（`海军将领`,`国籍`,`国家`）与（`州`,`隶属`,`国家`），为了在基于本体规则的补全那里做演示。
# 这里将数据构造好之后顺便插入了图数据库，方便查看。

# %%
import pandas as pd
from tqdm import tqdm
df = pd.read_excel('./triples_10_16.xlsx') # 十一打击群元组
triples = df.values.tolist()
## 插入本体中叶子结点的图结构
graph_11 = set()
for triple in triples:
    h, h_t, t, t_t, r = triple
    graph_11.add((h_t, all_node_type ,r , t_t, all_node_type))
# graph_11.add(('海军将领', all_node_type, '国籍', '国家', all_node_type))
# graph_11.add(('州', all_node_type, '隶属', '国家', all_node_type))
graph_11 = list(graph_11)
eleven_strike_swarms_graph_structure = set()
for triple in tqdm(graph_11):
    head, head_typ, rel, tail, tail_typ = triple
    node1 = Node(head_typ, name=head)
    node2 = Node(tail_typ, name=tail)
    graph.merge(node1, head_typ, "name")
    graph.merge(node2, tail_typ, "name")
    graph.create(Relationship(node1, rel, node2))
    eleven_strike_swarms_graph_structure.add((head, rel, tail))
# Out:
# 100%|██████████| 41/41 [00:02<00:00, 15.95it/s]

# %% [markdown]
# #### 3 构建“十一打击群”概念图谱-树结构
# 这部分的数据是通过观察核心本体树，并且将现有的类别挂载到本体树上来构成的。
# 同样，构造好的树结构通过图数据库来展示。

# %%
## thing与第一层本体类别的连接
first_layer = ['资源', '环境', '使命', '场景', '活动', '目标', '能力', '计划', '指导', '位置', '度量', '结果']
eleven_strike_swarms_tree_structure = set()
node_thing = Node(all_node_type, name='Thing')
graph.merge(node_thing , all_node_type, "name")
for node in first_layer:
    node_fl = Node(all_node_type, name=node)
    graph.merge(node_fl, all_node_type, "name")
    graph.create(Relationship(node_fl, '属于', node_thing))
    eleven_strike_swarms_tree_structure.add((node, '属于', 'Thing'))
## 资源与第二层本体类别的连接
node_resource = Node(all_node_type, name='资源')
graph.merge(node_resource , all_node_type, "name")
layer_after_resource = ['装备物资', '执行者', '国防工程', '信息']
for node in layer_after_resource:
    node_fl = Node(all_node_type, name=node)
    graph.merge(node_fl, all_node_type, "name")
    graph.create(Relationship(node_fl, '属于', node_resource))
    eleven_strike_swarms_tree_structure.add((node, '属于', '资源'))
## 装备物资与其子结点的连接
node_equip = Node(all_node_type, name='装备物资')
graph.merge(node_equip , all_node_type, "name")
layer_after_equip = ['火炮', '坦克装甲车辆', '枪械与单兵', '太空装备', '爆炸物', '舰船舰艇', '飞行器', '导弹武器']
for node in layer_after_equip:
    node_fl = Node(all_node_type, name=node)
    graph.merge(node_fl, all_node_type, "name")
    graph.create(Relationship(node_fl, '属于', node_equip))
    eleven_strike_swarms_tree_structure.add((node, '属于', '装备物资'))
## 国防工程
node_natidefe = Node(all_node_type, name='国防工程')
graph.merge(node_natidefe , all_node_type, "name")
layer_after_natidefe = ['研发单位', '海军基地', '制造厂']
for node in layer_after_natidefe:
    node_fl = Node(all_node_type, name=node)
    graph.merge(node_fl, all_node_type, "name")
    graph.create(Relationship(node_fl, '属于', node_natidefe))
    eleven_strike_swarms_tree_structure.add((node, '属于', '国防工程'))
## 执行者
node_executor = Node(all_node_type, name='执行者')
graph.merge(node_executor, all_node_type, "name")
layer_after_executor = ['海军将领', '舰载机联队', '驱逐舰中队', '作战中队']
for node in layer_after_executor:
    node_fl = Node(all_node_type, name=node)
    graph.merge(node_fl, all_node_type, "name")
    graph.create(Relationship(node_fl, '属于', node_executor))
    eleven_strike_swarms_tree_structure.add((node, '属于', '执行者'))
## 位置
node_location = Node(all_node_type, name='位置')
graph.merge(node_location, all_node_type, "name")
node_country = Node(all_node_type, name='国家')
graph.merge(node_country, all_node_type, "name")
graph.create(Relationship(node_country, '属于', node_location))
eleven_strike_swarms_tree_structure.add(('国家', '属于', '位置'))
layer_after_country = ['州', '地区']
for node in layer_after_country:
    node_fl = Node(all_node_type, name=node)
    graph.merge(node_fl, all_node_type, "name")
    graph.create(Relationship(node_fl, '属于', node_country))
    eleven_strike_swarms_tree_structure.add((node, '属于', '国家'))
## 舰船舰艇
node_naval_equipment = Node(all_node_type, name='舰船舰艇')
graph.merge(node_naval_equipment, all_node_type, "name")
layer_after_naval_equipment = ['航空母舰','驱逐舰','巡洋舰','补给舰','航母打击群']
for node in layer_after_naval_equipment:
    node_fl = Node(all_node_type, name=node)
    graph.merge(node_fl, all_node_type, "name")
    graph.create(Relationship(node_fl, '属于', node_naval_equipment))
    eleven_strike_swarms_tree_structure.add((node, '属于', '舰船舰艇'))

# %% [markdown]
# #### 4 构建“装备知识图谱”概念图谱-图结构

# %%
from pprint import pprint
graph_11 = set()
openkg = load_pickle_file('equipment_kg.pkl')
for triple in openkg:
    h, h_t,r, t, t_t,  = triple
    graph_11.add((h_t, all_node_type ,r , t_t, all_node_type))
graph_11 = list(graph_11)
knowledge_graph_of_equipment_graph_structure = set()
for triple in tqdm(graph_11):
    head, head_typ, rel, tail, tail_typ = triple
    node1 = Node(head_typ, name=head)
    node2 = Node(tail_typ, name=tail)
    graph.merge(node1, head_typ, "name")
    graph.merge(node2, tail_typ, "name")
    graph.create(Relationship(node1, rel, node2))
    knowledge_graph_of_equipment_graph_structure.add((head, rel, tail))
# Out:
# 100%|██████████| 165/165 [00:01<00:00, 98.75it/s]

# %% [markdown]
# #### 5 构建“装备知识图谱”概念图谱-树结构
# 注意这里是将“装备知识图谱”中的类别挂到了之前在之前由“十一打击群”形成的本体上，如果想单独生成“装备知识图谱”的本体，请使用代码6。

# %%
import json
from tqdm import tqdm
def load_military_json():
    """加载military的json文件"""
    with open("./military_format.json",'r',encoding='utf-8') as load_f:
        load_dict = json.load(load_f)
    return load_dict
openkg = load_military_json()
knowledge_graph_of_equipment_tree_structure = set()
## 链接装备类型与装备大类
for equip_dict in tqdm(openkg):
    node1 = Node(all_node_type, name=equip_dict['类型'])
    node2 = Node(all_node_type, name=equip_dict['大类'])
    graph.merge(node1, all_node_type, "name")
    graph.merge(node2, all_node_type, "name")
    graph.create(Relationship(node1, '属于', node2))
    knowledge_graph_of_equipment_tree_structure.add((equip_dict['类型'], '属于', equip_dict['大类']))
# Out:
# 100%|██████████| 5800/5800 [00:41<00:00, 138.87it/s]

# %% [markdown]
# #### 6 装备知识图谱的树结构（从thing开始）

# %%
import json
from tqdm import tqdm
def load_military_json():
    """加载military的json文件"""
    with open("./military_format.json",'r',encoding='utf-8') as load_f:
        load_dict = json.load(load_f)
    return load_dict
openkg = load_military_json()
## 装备物资与其子结点的连接
node_equip = Node(all_node_type, name='Thing')
graph.merge(node_equip , all_node_type, "name")
layer_after_equip = ['火炮', '坦克装甲车辆', '枪械与单兵', '太空装备', '爆炸物', '舰船舰艇', '飞行器', '导弹武器']
for node in layer_after_equip:
    node_fl = Node(all_node_type, name=node)
    graph.merge(node_fl, all_node_type, "name")
    graph.create(Relationship(node_fl, '属于', node_equip))
## 链接装备类型与装备大类
for equip_dict in tqdm(openkg):
    node1 = Node(all_node_type, name=equip_dict['类型'])
    node2 = Node(all_node_type, name=equip_dict['大类'])
    graph.merge(node1, all_node_type, "name")
    graph.merge(node2, all_node_type, "name")
    graph.create(Relationship(node1, '属于', node2))
# Out:
# 100%|██████████| 5800/5800 [00:39<00:00, 146.14it/s]

# %% [markdown]
# #### 7 保存本体的图结构和树结构
# 如果需要则将以上生成的结构保存为pkl文件。

# %%
# save_as_pickle(eleven_strike_swarms_tree_structure, 'eleven_strike_swarms_tree_structure')
# save_as_pickle(eleven_strike_swarms_graph_structure, 'eleven_strike_swarms_graph_structure')
# save_as_pickle(knowledge_graph_of_equipment_tree_structure, 'knowledge_graph_of_equipment_tree_structure')
# save_as_pickle(knowledge_graph_of_equipment_graph_structure, 'knowledge_graph_of_equipment_graph_structure')
# pprint(eleven_strike_swarms_graph_structure)
# pprint(knowledge_graph_of_equipment_tree_structure)
# pprint(knowledge_graph_of_equipment_graph_structure)
# pprint(load_pickle_file('eleven_strike_swarms_tree_structure.pkl'))
# pprint(load_pickle_file('eleven_strike_swarms_graph_structure.pkl'))
# pprint(load_pickle_file('knowledge_graph_of_equipment_tree_structure.pkl'))
# pprint(load_pickle_file('knowledge_graph_of_equipment_graph_structure.pkl'))

# %% [markdown]
# #### 8 构建“十一打击群”图谱
# “十一打击群”五元组数据

# %%
from py2neo import Graph, Node, Relationship, Graph, NodeMatcher, RelationshipMatcher
graph = Graph('http://localhost:7474', auth=('neo4j', 'Sicdp2021cjw'))
graph.delete_all() # 清空图数据库
import pandas as pd
from tqdm import tqdm
df = pd.read_excel('E:/neo4j/triples_10_16.xlsx')
triples = df.values.tolist()
new_triples = []
for triple in triples:
    new_triple = []
    for str in triple:
        str = ''.join(str.split()) # 去掉空格字符
        new_triple.append(str)
    new_triples.append(new_triple)
for triple in tqdm(new_triples):
    head, head_typ, tail, tail_typ, rel = triple # 取出头实体、尾实体、关系
    head_node = Node(head_typ, name=head)
    tail_node = Node(tail_typ, name=tail)
    graph.merge(head_node, head_typ, "name")
    graph.merge(tail_node, tail_typ, "name")                  
    graph.create(Relationship(head_node, rel, tail_node))
new_triples
# Out:
# 100%|██████████| 357/357 [00:03<00:00, 109.07it/s]
# [['第十一航母打击群', '航母打击群', '尼米兹号航空母舰', '航空母舰', '航空母舰'],
#  ['第十一航母打击群', '航母打击群', '第17舰载机联队', '舰载机联队', '舰载机联队'],
#  ['第十一航母打击群', '航母打击群', '第9驱逐舰中队', '驱逐舰中队', '驱逐舰中队'],
#  ['第十一航母打击群', '航母打击群', '埃弗里特海军基地', '海军基地', '母港'],
#  ['埃弗里特海军基地', '海军基地', '华盛顿州', '州', '位置'],
#  ['第17舰载机联队', '舰载机联队', '第22突击战斗机中队', '作战中队', '作战中队'],
#  ['第17舰载机联队', '舰载机联队', '第94突击战斗机中队', '作战中队', '作战中队'],
#  ['第17舰载机联队', '舰载机联队', '第137突击战斗机中队', '作战中队', '作战中队'],
#  ['第17舰载机联队', '舰载机联队', '第323海军陆战队攻击中队', '作战中队', '作战中队'],
#  ['第17舰载机联队', '舰载机联队', '第139电子攻击中队', '作战中队', '作战中队'],
#  ['第17舰载机联队', '舰载机联队', '第116航母机载预警中队', '作战中队', '作战中队'],
#  ['第17舰载机联队', '舰载机联队', '第6直升机海上作战中队', '作战中队', '作战中队'],
#  ['第17舰载机联队', '舰载机联队', '第73直升机海上打击中队', '作战中队', '作战中队'],
#  ['第17舰载机联队', '舰载机联队', '第30舰队后勤支援中队第4分队', '作战中队', '作战中队'],
#  ['第9驱逐舰中队', '驱逐舰中队', '约翰保罗琼斯号导弹驱逐舰', '驱逐舰', '驱逐舰'],
#  ['第9驱逐舰中队', '驱逐舰中队', '韦恩·迈耶号导弹驱逐舰', '驱逐舰', '驱逐舰'],
#  ['第9驱逐舰中队', '驱逐舰中队', '斯特雷特号导弹驱逐舰', '驱逐舰', '驱逐舰'],
#  ['第9驱逐舰中队', '驱逐舰中队', '拉尔夫·约翰逊号导弹驱逐舰', '驱逐舰', '驱逐舰'],
#  ['第9驱逐舰中队', '驱逐舰中队', '柯蒂斯·威尔伯号导弹驱逐舰', '驱逐舰', '驱逐舰'],
#  ['第9驱逐舰中队', '驱逐舰中队', '邦克山号导弹巡洋舰', '巡洋舰', '巡洋舰'],
#  ['第9驱逐舰中队', '驱逐舰中队', '伊利湖号导弹巡洋舰', '巡洋舰', '巡洋舰'],
#  ['第9驱逐舰中队', '驱逐舰中队', '普林斯顿号导弹巡洋舰', '巡洋舰', '巡洋舰'],
#  ['第9驱逐舰中队', '驱逐舰中队', '育空号补给舰', '补给舰', '补给舰'],
#  ['第9驱逐舰中队', '驱逐舰中队', '帕特里克·H·奥马奥尼', '海军将领', '指挥官'],
#  ['第9驱逐舰中队', '驱逐舰中队', '拉里·雷帕斯', '海军将领', '执行官'],
#  ['第9驱逐舰中队', '驱逐舰中队', '珍妮特·哈弗', '海军将领', '指挥军士长'],
#  ['约翰保罗琼斯号导弹驱逐舰', '驱逐舰', '罗伯特·富兰克林', '海军将领', '指挥官'],
#  ['约翰保罗琼斯号导弹驱逐舰', '驱逐舰', '布赖恩·劳斯', '海军将领', '执行官'],
#  ['约翰保罗琼斯号导弹驱逐舰', '驱逐舰', '约书亚B.乔纳', '海军将领', '指挥军士长'],
#  ['韦恩·迈耶号导弹驱逐舰', '驱逐舰', '克里斯托弗·J·格林', '海军将领', '指挥官'],
#  ['韦恩·迈耶号导弹驱逐舰', '驱逐舰', '罗纳德·C·费尔班克斯', '海军将领', '执行官'],
#  ['韦恩·迈耶号导弹驱逐舰', '驱逐舰', '加里·拜鲁姆', '海军将领', '指挥军士长'],
#  ['斯特雷特号导弹驱逐舰', '驱逐舰', '克里斯托弗·M·德斯科维奇', '海军将领', '指挥官'],
#  ['斯特雷特号导弹驱逐舰', '驱逐舰', '杰森·加菲尔德', '海军将领', '执行官'],
#  ['斯特雷特号导弹驱逐舰', '驱逐舰', '阿尔弗雷多·N·阿隆索', '海军将领', '指挥军士长'],
#  ['拉尔夫·约翰逊号导弹驱逐舰', '驱逐舰', '科林·罗伯茨', '海军将领', '指挥官'],
#  ['拉尔夫·约翰逊号导弹驱逐舰', '驱逐舰', '以赛亚·因凡特', '海军将领', '执行官'],
#  ['拉尔夫·约翰逊号导弹驱逐舰', '驱逐舰', '大卫·凯悦', '海军将领', '指挥军士长'],
#  ['柯蒂斯·威尔伯号导弹驱逐舰', '驱逐舰', '约瑟夫·福斯特', '海军将领', '指挥官'],
#  ['柯蒂斯·威尔伯号导弹驱逐舰', '驱逐舰', '莎拉·林奇', '海军将领', '执行官'],
#  ['柯蒂斯·威尔伯号导弹驱逐舰', '驱逐舰', '威廉姆斯·艾利', '海军将领', '指挥军士长'],
#  ['邦克山号导弹巡洋舰', '巡洋舰', '杰森·爱德华·罗杰斯', '海军将领', '指挥官'],
#  ['邦克山号导弹巡洋舰', '巡洋舰', '丹·科尔贝克', '海军将领', '执行官'],
#  ['邦克山号导弹巡洋舰', '巡洋舰', '亚伦·温伯利', '海军将领', '指挥军士长'],
#  ['伊利湖号导弹巡洋舰', '巡洋舰', '丹妮尔·C·德范特', '海军将领', '指挥官'],
#  ['伊利湖号导弹巡洋舰', '巡洋舰', '卡尔·P·坡', '海军将领', '执行官'],
#  ['伊利湖号导弹巡洋舰', '巡洋舰', '兰迪·斯旺森', '海军将领', '指挥军士长'],
#  ['普林斯顿号导弹巡洋舰', '巡洋舰', '马丁·罗伯逊', '海军将领', '指挥官'],
#  ['普林斯顿号导弹巡洋舰', '巡洋舰', '马修·托德', '海军将领', '执行官'],
#  ['普林斯顿号导弹巡洋舰', '巡洋舰', '雷吉塔·佩里', '海军将领', '指挥军士长'],
#  ['帕特里克·H·奥马奥尼', '海军将领', '拉里·雷帕斯', '海军将领', '同事'],
#  ['帕特里克·H·奥马奥尼', '海军将领', '珍妮特·哈弗', '海军将领', '同事'],
#  ['拉里·雷帕斯', '海军将领', '帕特里克·H·奥马奥尼', '海军将领', '同事'],
#  ['拉里·雷帕斯', '海军将领', '珍妮特·哈弗', '海军将领', '同事'],
#  ['珍妮特·哈弗', '海军将领', '帕特里克·H·奥马奥尼', '海军将领', '同事'],
#  ['珍妮特·哈弗', '海军将领', '拉里·雷帕斯', '海军将领', '同事'],
#  ['罗伯特·富兰克林', '海军将领', '布赖恩·劳斯', '海军将领', '同事'],
#  ['罗伯特·富兰克林', '海军将领', '约书亚B.乔纳', '海军将领', '同事'],
#  ['布赖恩·劳斯', '海军将领', '罗伯特·富兰克林', '海军将领', '同事'],
#  ['布赖恩·劳斯', '海军将领', '约书亚B.乔纳', '海军将领', '同事'],
#  ['约书亚B.乔纳', '海军将领', '罗伯特·富兰克林', '海军将领', '同事'],
#  ['约书亚B.乔纳', '海军将领', '布赖恩·劳斯', '海军将领', '同事'],
#  ['克里斯托弗·J·格林', '海军将领', '罗纳德·C·费尔班克斯', '海军将领', '同事'],
#  ['克里斯托弗·J·格林', '海军将领', '加里·拜鲁姆', '海军将领', '同事'],
#  ['罗纳德·C·费尔班克斯', '海军将领', '克里斯托弗·J·格林', '海军将领', '同事'],
#  ['罗纳德·C·费尔班克斯', '海军将领', '加里·拜鲁姆', '海军将领', '同事'],
#  ['加里·拜鲁姆', '海军将领', '罗纳德·费尔班克斯', '海军将领', '同事'],
#  ['加里·拜鲁姆', '海军将领', '克里斯托弗·J·格林', '海军将领', '同事'],
#  ['克里斯托弗·M·德斯科维奇', '海军将领', '杰森·加菲尔德', '海军将领', '同事'],
#  ['克里斯托弗·M·德斯科维奇', '海军将领', '阿尔弗雷多·N·阿隆索', '海军将领', '同事'],
#  ['杰森·加菲尔德', '海军将领', '克里斯托弗·M·德斯科维奇', '海军将领', '同事'],
#  ['杰森·加菲尔德', '海军将领', '阿尔弗雷多·N·阿隆索', '海军将领', '同事'],
#  ['阿尔弗雷多·N·阿隆索', '海军将领', '克里斯托弗·M·德斯科维奇', '海军将领', '同事'],
#  ['阿尔弗雷多·N·阿隆索', '海军将领', '杰森·加菲尔德', '海军将领', '同事'],
#  ['科林·罗伯茨', '海军将领', '以赛亚·因凡特', '海军将领', '同事'],
#  ['科林·罗伯茨', '海军将领', '大卫·凯悦', '海军将领', '同事'],
#  ['以赛亚·因凡特', '海军将领', '科林·罗伯茨', '海军将领', '同事'],
#  ['以赛亚·因凡特', '海军将领', '大卫·凯悦', '海军将领', '同事'],
#  ['大卫·凯悦', '海军将领', '科林·罗伯茨', '海军将领', '同事'],
#  ['大卫·凯悦', '海军将领', '以赛亚·因凡特', '海军将领', '同事'],
#  ['约瑟夫·福斯特', '海军将领', '莎拉·林奇', '海军将领', '同事'],
#  ['约瑟夫·福斯特', '海军将领', '威廉姆斯·艾利', '海军将领', '同事'],
#  ['莎拉·林奇', '海军将领', '约瑟夫·福斯特', '海军将领', '同事'],
#  ['莎拉·林奇', '海军将领', '威廉姆斯·艾利', '海军将领', '同事'],
#  ['威廉姆斯·艾利', '海军将领', '约瑟夫·福斯特', '海军将领', '同事'],
#  ['威廉姆斯·艾利', '海军将领', '莎拉·林奇', '海军将领', '同事'],
#  ['杰森·爱德华·罗杰斯', '海军将领', '丹·科尔贝克', '海军将领', '同事'],
#  ['杰森·爱德华·罗杰斯', '海军将领', '亚伦·温伯利', '海军将领', '同事'],
#  ['丹·科尔贝克', '海军将领', '杰森·爱德华·罗杰斯', '海军将领', '同事'],
#  ['丹·科尔贝克', '海军将领', '亚伦·温伯利', '海军将领', '同事'],
#  ['亚伦·温伯利', '海军将领', '杰森·爱德华·罗杰斯', '海军将领', '同事'],
#  ['亚伦·温伯利', '海军将领', '丹·科尔贝克', '海军将领', '同事'],
#  ['丹妮尔·C·德范特', '海军将领', '卡尔·P·坡', '海军将领', '同事'],
#  ['丹妮尔·C·德范特', '海军将领', '兰迪·斯旺森', '海军将领', '同事'],
#  ['卡尔·P·坡', '海军将领', '丹妮尔·C·德范特', '海军将领', '同事'],
#  ['卡尔·P·坡', '海军将领', '兰迪·斯旺森', '海军将领', '同事'],
#  ['兰迪·斯旺森', '海军将领', '丹妮尔·C·德范特', '海军将领', '同事'],
#  ['兰迪·斯旺森', '海军将领', '卡尔·P·坡', '海军将领', '同事'],
#  ['马丁·罗伯逊', '海军将领', '马修·托德', '海军将领', '同事'],
#  ['马丁·罗伯逊', '海军将领', '雷吉塔·佩里', '海军将领', '同事'],
#  ['马修·托德', '海军将领', '马丁·罗伯逊', '海军将领', '同事'],
#  ['马修·托德', '海军将领', '雷吉塔·佩里', '海军将领', '同事'],
#  ['雷吉塔·佩里', '海军将领', '马丁·罗伯逊', '海军将领', '同事'],
#  ['雷吉塔·佩里', '海军将领', '马修·托德', '海军将领', '同事'],
#  ['帕特里克·H·奥马奥尼', '海军将领', '北卡罗来纳州', '州', '家庭信息'],
#  ['拉里·雷帕斯', '海军将领', '伊利诺伊州', '州', '家庭信息'],
#  ['珍妮特·哈弗', '海军将领', '伊利诺伊州', '州', '家庭信息'],
#  ['罗伯特·富兰克林', '海军将领', '乔治亚州', '州', '家庭信息'],
#  ['布赖恩·劳斯', '海军将领', '罗德岛州', '州', '家庭信息'],
#  ['约书亚B.乔纳', '海军将领', '德克萨斯州', '州', '家庭信息'],
#  ['克里斯托弗·J·格林', '海军将领', '犹他州', '州', '家庭信息'],
#  ['罗纳德·C·费尔班克斯', '海军将领', '加利福尼亚州', '州', '家庭信息'],
#  ['加里·拜鲁姆', '海军将领', '马里兰州', '州', '家庭信息'],
#  ['克里斯托弗·M·德斯科维奇', '海军将领', '加利福尼亚州', '州', '家庭信息'],
#  ['杰森·加菲尔德', '海军将领', '马萨诸塞州', '州', '家庭信息'],
#  ['阿尔弗雷多·N·阿隆索', '海军将领', '马萨诸塞州', '州', '家庭信息'],
#  ['科林·罗伯茨', '海军将领', '华盛顿州', '州', '家庭信息'],
#  ['以赛亚·因凡特', '海军将领', '华盛顿州', '州', '家庭信息'],
#  ['大卫·凯悦', '海军将领', '俄亥俄州', '州', '家庭信息'],
#  ['约瑟夫·福斯特', '海军将领', '宾夕法尼亚州', '州', '家庭信息'],
#  ['莎拉·林奇', '海军将领', '纽约州', '州', '家庭信息'],
#  ['威廉姆斯·艾利', '海军将领', '佛罗里达州', '州', '家庭信息'],
#  ['杰森·爱德华·罗杰斯', '海军将领', '马萨诸塞州', '州', '家庭信息'],
#  ['丹·科尔贝克', '海军将领', '华盛顿州', '州', '家庭信息'],
#  ['亚伦·温伯利', '海军将领', '俄亥俄州', '州', '家庭信息'],
#  ['丹妮尔·C·德范特', '海军将领', '加利福尼亚州', '州', '家庭信息'],
#  ['卡尔·P·坡', '海军将领', '弗吉尼亚州', '州', '家庭信息'],
#  ['兰迪·斯旺森', '海军将领', '加利福尼亚州', '州', '家庭信息'],
#  ['马丁·罗伯逊', '海军将领', '宾夕法尼亚州', '州', '家庭信息'],
#  ['马修·托德', '海军将领', '马里兰州', '州', '家庭信息'],
#  ['雷吉塔·佩里', '海军将领', '俄克拉荷马州', '州', '家庭信息'],
#  ['第十一航母打击群', '航母打击群', '克里斯托弗·斯威尼', '海军将领', '指挥官'],
#  ['第十一航母打击群', '航母打击群', '杰森威尔斯', '海军将领', '参谋长'],
#  ['第十一航母打击群', '航母打击群', '约翰·沃克', '海军将领', '指挥军士长'],
#  ['尼米兹号航空母舰', '航空母舰', '克雷格·西科拉', '海军将领', '指挥官'],
#  ['尼米兹号航空母舰', '航空母舰', '克里斯托弗·莱尔斯', '海军将领', '指挥军士长'],
#  ['尼米兹号航空母舰', '航空母舰', '约书亚·温克', '海军将领', '执行官'],
#  ['第17舰载机联队', '舰载机联队', '克里斯托弗·赫斯特', '海军将领', '指挥官'],
#  ['第17舰载机联队', '舰载机联队', '詹姆斯·M·金特', '海军将领', '总舰长'],
#  ['第17舰载机联队', '舰载机联队', '兰德尔·T·博宁', '海军将领', '指挥军事长'],
#  ['第22突击战斗机中队', '作战中队', '卢克“SUDS”爱德华兹', '海军将领', '指挥官'],
#  ['第22突击战斗机中队', '作战中队', '乔纳森“Skirmish”套衫', '海军将领', '执行官'],
#  ['第22突击战斗机中队', '作战中队', '亨特', '海军将领', '指挥军士长'],
#  ['第94突击战斗机中队', '作战中队', '迈克坎贝尔', '海军将领', '指挥官'],
#  ['第94突击战斗机中队', '作战中队', '兰迪“JP”科南特', '海军将领', '执行官'],
#  ['第94突击战斗机中队', '作战中队', '普尼阿莱法约', '海军将领', '指挥军士长'],
#  ['第137突击战斗机中队', '作战中队', '凯利MagooDossenback', '海军将领', '指挥官'],
#  ['第137突击战斗机中队', '作战中队', '亚当“吉利根”布莱恩', '海军将领', '执行官'],
#  ['第137突击战斗机中队', '作战中队', '迪尔德丽·A·帕克', '海军将领', '指挥军士长'],
#  ['第323海军陆战队攻击中队', '作战中队', '布拉德福德J.GERING', '海军将领', '指挥官'],
#  ['第323海军陆战队攻击中队', '作战中队', '布罗迪', '海军将领', '执行官'],
#  ['第323海军陆战队攻击中队', '作战中队', '埃里克·加西亚', '海军将领', '指挥军士长'],
#  ['第139电子攻击中队', '作战中队', '雅各布·弗巴斯', '海军将领', '指挥官'],
#  ['第139电子攻击中队', '作战中队', '凯文·琼斯', '海军将领', '执行官'],
#  ['第139电子攻击中队', '作战中队', '莫里斯', '海军将领', '指挥军士长'],
#  ['克里斯托弗·斯威尼', '海军将领', '马里兰州', '州', '家庭信息'],
#  ['杰森威尔斯', '海军将领', '夏威夷州', '州', '家庭信息'],
#  ['约翰·沃克', '海军将领', '乔治亚州', '州', '家庭信息'],
#  ['克雷格·西科拉', '海军将领', '德克萨斯州', '州', '家庭信息'],
#  ['约书亚·温克', '海军将领', '伊利诺伊州', '州', '家庭信息'],
#  ['克里斯托弗·莱尔斯', '海军将领', 'unknown', '州', '家庭信息'],
#  ['克里斯托弗·赫斯特', '海军将领', '威斯康星州', '州', '家庭信息'],
#  ['詹姆斯·M·金特', '海军将领', '加利福尼亚州', '州', '家庭信息'],
#  ['兰德尔·T·博宁', '海军将领', '蒙大拿州', '州', '家庭信息'],
#  ['卢克“SUDS”爱德华兹', '海军将领', '田纳西州', '州', '家庭信息'],
#  ['乔纳森“Skirmish”套衫', '海军将领', '佛罗里达州', '州', '家庭信息'],
#  ['亨特', '海军将领', '缅因州', '州', '家庭信息'],
#  ['迈克坎贝尔', '海军将领', '特拉华州', '州', '家庭信息'],
#  ['兰迪“JP”科南特', '海军将领', '缅因州', '州', '家庭信息'],
#  ['普尼阿莱法约', '海军将领', '美属萨摩亚', '地区', '家庭信息'],
#  ['凯利MagooDossenback', '海军将领', '俄亥俄州', '州', '家庭信息'],
#  ['亚当“吉利根”布莱恩', '海军将领', '康涅狄格州', '州', '家庭信息'],
#  ['迪尔德丽·A·帕克', '海军将领', '德克萨斯州', '州', '家庭信息'],
#  ['布拉德福德J.GERING', '海军将领', '纽约州', '州', '家庭信息'],
#  ['布罗迪', '海军将领', '宾夕法尼亚州', '州', '家庭信息'],
#  ['埃里克·加西亚', '海军将领', '新墨西哥州', '州', '家庭信息'],
#  ['雅各布·弗巴斯', '海军将领', '堪萨斯州', '州', '家庭信息'],
#  ['凯文·琼斯', '海军将领', '弗吉尼亚州', '州', '家庭信息'],
#  ['莫里斯', '海军将领', '德克萨斯州', '州', '家庭信息'],
#  ['克里斯托弗·斯威尼', '海军将领', '杰森威尔斯', '海军将领', '同事'],
#  ['克里斯托弗·斯威尼', '海军将领', '约翰·沃克', '海军将领', '同事'],
#  ['杰森威尔斯', '海军将领', '克里斯托弗·斯威尼', '海军将领', '同事'],
#  ['杰森威尔斯', '海军将领', '约翰·沃克', '海军将领', '同事'],
#  ['约翰·沃克', '海军将领', '杰森威尔斯', '海军将领', '同事'],
#  ['约翰·沃克', '海军将领', '克里斯托弗·斯威尼', '海军将领', '同事'],
#  ['克雷格·西科拉', '海军将领', '约书亚·温克', '海军将领', '同事'],
#  ['克雷格·西科拉', '海军将领', '克里斯托弗·莱尔斯', '海军将领', '同事'],
#  ['克里斯托弗·莱尔斯', '海军将领', '克雷格·西科拉', '海军将领', '同事'],
#  ['克里斯托弗·莱尔斯', '海军将领', '约书亚·温克', '海军将领', '同事'],
#  ['约书亚·温克', '海军将领', '克雷格·西科拉', '海军将领', '同事'],
#  ['约书亚·温克', '海军将领', '克里斯托弗·莱尔斯', '海军将领', '同事'],
#  ['克里斯托弗·赫斯特', '海军将领', '詹姆斯·M·金特', '海军将领', '同事'],
#  ['克里斯托弗·赫斯特', '海军将领', '兰德尔·T·博宁', '海军将领', '同事'],
#  ['詹姆斯·M·金特', '海军将领', '克里斯托弗·赫斯特', '海军将领', '同事'],
#  ['詹姆斯·M·金特', '海军将领', '兰德尔·T·博宁', '海军将领', '同事'],
#  ['兰德尔·T·博宁', '海军将领', '克里斯托弗·赫斯特', '海军将领', '同事'],
#  ['兰德尔·T·博宁', '海军将领', '詹姆斯·M·金特', '海军将领', '同事'],
#  ['卢克“SUDS”爱德华兹', '海军将领', '乔纳森“Skirmish”套衫', '海军将领', '同事'],
#  ['卢克“SUDS”爱德华兹', '海军将领', '亨特', '海军将领', '同事'],
#  ['乔纳森“Skirmish”套衫', '海军将领', '卢克“SUDS”爱德华兹', '海军将领', '同事'],
#  ['乔纳森“Skirmish”套衫', '海军将领', '亨特', '海军将领', '同事'],
#  ['亨特', '海军将领', '卢克“SUDS”爱德华兹', '海军将领', '同事'],
#  ['亨特', '海军将领', '乔纳森“Skirmish”套衫', '海军将领', '同事'],
#  ['迈克坎贝尔', '海军将领', '普尼阿莱法约', '海军将领', '同事'],
#  ['迈克坎贝尔', '海军将领', '兰迪“JP”科南特', '海军将领', '同事'],
#  ['兰迪“JP”科南特', '海军将领', '迈克坎贝尔', '海军将领', '同事'],
#  ['兰迪“JP”科南特', '海军将领', '普尼阿莱法约', '海军将领', '同事'],
#  ['普尼阿莱法约', '海军将领', '迈克坎贝尔', '海军将领', '同事'],
#  ['普尼阿莱法约', '海军将领', '兰迪“JP”科南特', '海军将领', '同事'],
#  ['凯利MagooDossenback', '海军将领', '亚当“吉利根”布莱恩', '海军将领', '同事'],
#  ['凯利MagooDossenback', '海军将领', '迪尔德丽·A·帕克', '海军将领', '同事'],
#  ['亚当“吉利根”布莱恩', '海军将领', '凯利MagooDossenback', '海军将领', '同事'],
#  ['亚当“吉利根”布莱恩', '海军将领', '迪尔德丽·A·帕克', '海军将领', '同事'],
#  ['迪尔德丽·A·帕克', '海军将领', '凯利MagooDossenback', '海军将领', '同事'],
#  ['迪尔德丽·A·帕克', '海军将领', '亚当“吉利根”布莱恩', '海军将领', '同事'],
#  ['布拉德福德J.GERING', '海军将领', '布罗迪', '海军将领', '同事'],
#  ['布拉德福德J.GERING', '海军将领', '埃里克·加西亚', '海军将领', '同事'],
#  ['布罗迪', '海军将领', '布拉德福德J.GERING', '海军将领', '同事'],
#  ['布罗迪', '海军将领', '埃里克·加西亚', '海军将领', '同事'],
#  ['埃里克·加西亚', '海军将领', '布拉德福德J.GERING', '海军将领', '同事'],
#  ['埃里克·加西亚', '海军将领', '布罗迪', '海军将领', '同事'],
#  ['雅各布·弗巴斯', '海军将领', '凯文·琼斯', '海军将领', '同事'],
#  ['雅各布·弗巴斯', '海军将领', '莫里斯', '海军将领', '同事'],
#  ['凯文·琼斯', '海军将领', '雅各布·弗巴斯', '海军将领', '同事'],
#  ['凯文·琼斯', '海军将领', '莫里斯', '海军将领', '同事'],
#  ['莫里斯', '海军将领', '雅各布·弗巴斯', '海军将领', '同事'],
#  ['莫里斯', '海军将领', '凯文·琼斯', '海军将领', '同事'],
#  ['第6直升机海上作战中队', '作战中队', '克里斯托弗·K·怀特豪斯', '海军将领', '指挥官'],
#  ['第6直升机海上作战中队', '作战中队', '梅森·W·贝瑞', '海军将领', '执行官'],
#  ['第6直升机海上作战中队', '作战中队', '内森·希基', '海军将领', '指挥军士长'],
#  ['第73直升机海上打击中队', '作战中队', '贾米尔“Faceman”麦克丹尼尔', '海军将领', '指挥官'],
#  ['第73直升机海上打击中队', '作战中队', '斯科特“王牌”利平科特', '海军将领', '执行官'],
#  ['第73直升机海上打击中队', '作战中队', '大卫·J·塞奎拉', '海军将领', '指挥军士长'],
#  ['第30舰队后勤支援中队第4分队', '作战中队', '杰西卡·E·考德威尔', '海军将领', '指挥官'],
#  ['第30舰队后勤支援中队第4分队', '作战中队', '詹姆斯·J·莱特', '海军将领', '执行官'],
#  ['第30舰队后勤支援中队第4分队', '作战中队', '吉内恩·狄更斯', '海军将领', '指挥军士长'],
#  ['克里斯托弗·K·怀特豪斯', '海军将领', '弗吉尼亚州', '州', '家庭信息'],
#  ['梅森·W·贝瑞', '海军将领', '马萨诸塞州', '州', '家庭信息'],
#  ['内森·希基', '海军将领', '新罕布什尔州', '州', '家庭信息'],
#  ['贾米尔“Faceman”麦克丹尼尔', '海军将领', '俄亥俄州', '州', '家庭信息'],
#  ['斯科特“王牌”利平科特', '海军将领', '科罗拉多州', '州', '家庭信息'],
#  ['大卫·J·塞奎拉', '海军将领', '罗德岛州', '州', '家庭信息'],
#  ['杰西卡·E·考德威尔', '海军将领', '俄亥俄州', '州', '家庭信息'],
#  ['詹姆斯·J·莱特', '海军将领', '纽约州', '州', '家庭信息'],
#  ['吉内恩·狄更斯', '海军将领', '加利福尼亚州', '州', '家庭信息'],
#  ['克里斯托弗·K·怀特豪斯', '海军将领', '内森·希基', '海军将领', '同事'],
#  ['克里斯托弗·K·怀特豪斯', '海军将领', '梅森·W·贝瑞', '海军将领', '同事'],
#  ['梅森·W·贝瑞', '海军将领', '克里斯托弗·K·怀特豪斯', '海军将领', '同事'],
#  ['梅森·W·贝瑞', '海军将领', '内森·希基', '海军将领', '同事'],
#  ['内森·希基', '海军将领', '克里斯托弗·K·怀特豪斯', '海军将领', '同事'],
#  ['内森·希基', '海军将领', '梅森·W·贝瑞', '海军将领', '同事'],
#  ['贾米尔“Faceman”麦克丹尼尔', '海军将领', '斯科特“王牌”利平科特', '海军将领', '同事'],
#  ['贾米尔“Faceman”麦克丹尼尔', '海军将领', '大卫·J·塞奎拉', '海军将领', '同事'],
#  ['斯科特“王牌”利平科特', '海军将领', '贾米尔“Faceman”麦克丹尼尔', '海军将领', '同事'],
#  ['斯科特“王牌”利平科特', '海军将领', '大卫·J·塞奎拉', '海军将领', '同事'],
#  ['大卫·J·塞奎拉', '海军将领', '贾米尔“Faceman”麦克丹尼尔', '海军将领', '同事'],
#  ['大卫·J·塞奎拉', '海军将领', '斯科特“王牌”利平科特', '海军将领', '同事'],
#  ['杰西卡·E·考德威尔', '海军将领', '吉内恩·狄更斯', '海军将领', '同事'],
#  ['杰西卡·E·考德威尔', '海军将领', '詹姆斯·J·莱特', '海军将领', '同事'],
#  ['詹姆斯·J·莱特', '海军将领', '杰西卡·E·考德威尔', '海军将领', '同事'],
#  ['詹姆斯·J·莱特', '海军将领', '吉内恩·狄更斯', '海军将领', '同事'],
#  ['吉内恩·狄更斯', '海军将领', '杰西卡·E·考德威尔', '海军将领', '同事'],
#  ['吉内恩·狄更斯', '海军将领', '詹姆斯·J·莱特', '海军将领', '同事'],
#  ['邦克山号导弹巡洋舰', '巡洋舰', '英格尔斯造船厂', '制造厂', '制造厂'],
#  ['柯蒂斯·威尔伯号导弹驱逐舰', '驱逐舰', '巴斯钢铁造船厂', '制造厂', '制造厂'],
#  ['拉尔夫·约翰逊号导弹驱逐舰', '驱逐舰', '英格尔斯造船厂', '制造厂', '制造厂'],
#  ['尼米兹号航空母舰', '航空母舰', '纽波特纽斯造船及船坞公司', '制造厂', '制造厂'],
#  ['普林斯顿号导弹巡洋舰', '巡洋舰', '英格尔斯造船厂', '制造厂', '制造厂'],
#  ['斯特雷特号导弹驱逐舰', '驱逐舰', '巴斯钢铁造船厂', '制造厂', '制造厂'],
#  ['韦恩·迈耶号导弹驱逐舰', '驱逐舰', '巴斯钢铁造船厂', '制造厂', '制造厂'],
#  ['伊利湖号导弹巡洋舰', '巡洋舰', '巴斯钢铁造船厂', '制造厂', '制造厂'],
#  ['育空号补给舰', '补给舰', '埃文代尔造船厂', '制造厂', '制造厂'],
#  ['约翰保罗琼斯号导弹驱逐舰', '驱逐舰', '巴斯钢铁造船厂', '制造厂', '制造厂'],
#  ['约翰保罗琼斯号导弹驱逐舰', '驱逐舰', '美国', '国家', '产国'],
#  ['韦恩·迈耶号导弹驱逐舰', '驱逐舰', '美国', '国家', '产国'],
#  ['斯特雷特号导弹驱逐舰', '驱逐舰', '美国', '国家', '产国'],
#  ['拉尔夫·约翰逊号导弹驱逐舰', '驱逐舰', '美国', '国家', '产国'],
#  ['柯蒂斯·威尔伯号导弹驱逐舰', '驱逐舰', '美国', '国家', '产国'],
#  ['邦克山号导弹巡洋舰', '巡洋舰', '美国', '国家', '产国'],
#  ['伊利湖号导弹巡洋舰', '巡洋舰', '美国', '国家', '产国'],
#  ['普林斯顿号导弹巡洋舰', '巡洋舰', '美国', '国家', '产国'],
#  ['育空号补给舰', '补给舰', '美国', '国家', '产国'],
#  ['帕特里克·H·奥马奥尼', '海军将领', '美国', '国家', '国籍'],
#  ['拉里·雷帕斯', '海军将领', '美国', '国家', '国籍'],
#  ['珍妮特·哈弗', '海军将领', '美国', '国家', '国籍'],
#  ['罗伯特·富兰克林', '海军将领', '美国', '国家', '国籍'],
#  ['布赖恩·劳斯', '海军将领', '美国', '国家', '国籍'],
#  ['约书亚B.乔纳', '海军将领', '美国', '国家', '国籍'],
#  ['克里斯托弗·J·格林', '海军将领', '美国', '国家', '国籍'],
#  ['罗纳德·C·费尔班克斯', '海军将领', '美国', '国家', '国籍'],
#  ['加里·拜鲁姆', '海军将领', '美国', '国家', '国籍'],
#  ['克里斯托弗·M·德斯科维奇', '海军将领', '美国', '国家', '国籍'],
#  ['杰森·加菲尔德', '海军将领', '美国', '国家', '国籍'],
#  ['阿尔弗雷多·N·阿隆索', '海军将领', '美国', '国家', '国籍'],
#  ['科林·罗伯茨', '海军将领', '美国', '国家', '国籍'],
#  ['以赛亚·因凡特', '海军将领', '美国', '国家', '国籍'],
#  ['大卫·凯悦', '海军将领', '美国', '国家', '国籍'],
#  ['约瑟夫·福斯特', '海军将领', '美国', '国家', '国籍'],
#  ['莎拉·林奇', '海军将领', '美国', '国家', '国籍'],
#  ['威廉姆斯·艾利', '海军将领', '美国', '国家', '国籍'],
#  ['杰森·爱德华·罗杰斯', '海军将领', '美国', '国家', '国籍'],
#  ['丹·科尔贝克', '海军将领', '美国', '国家', '国籍'],
#  ['亚伦·温伯利', '海军将领', '美国', '国家', '国籍'],
#  ['丹妮尔·C·德范特', '海军将领', '美国', '国家', '国籍'],
#  ['卡尔·P·坡', '海军将领', '美国', '国家', '国籍'],
#  ['兰迪·斯旺森', '海军将领', '美国', '国家', '国籍'],
#  ['马丁·罗伯逊', '海军将领', '美国', '国家', '国籍'],
#  ['马修·托德', '海军将领', '美国', '国家', '国籍'],
#  ['雷吉塔·佩里', '海军将领', '美国', '国家', '国籍'],
#  ['克里斯托弗·斯威尼', '海军将领', '美国', '国家', '国籍'],
#  ['杰森威尔斯', '海军将领', '美国', '国家', '国籍'],
#  ['约翰·沃克', '海军将领', '美国', '国家', '国籍'],
#  ['克雷格·西科拉', '海军将领', '美国', '国家', '国籍'],
#  ['克里斯托弗·莱尔斯', '海军将领', '美国', '国家', '国籍'],
#  ['约书亚·温克', '海军将领', '美国', '国家', '国籍'],
#  ['克里斯托弗·赫斯特', '海军将领', '美国', '国家', '国籍'],
#  ['詹姆斯·M·金特', '海军将领', '美国', '国家', '国籍'],
#  ['兰德尔·T·博宁', '海军将领', '美国', '国家', '国籍'],
#  ['卢克“SUDS”爱德华兹', '海军将领', '美国', '国家', '国籍'],
#  ['乔纳森“Skirmish”套衫', '海军将领', '美国', '国家', '国籍'],
#  ['亨特', '海军将领', '美国', '国家', '国籍'],
#  ['迈克坎贝尔', '海军将领', '美国', '国家', '国籍'],
#  ['兰迪“JP”科南特', '海军将领', '美国', '国家', '国籍'],
#  ['普尼阿莱法约', '海军将领', '美国', '国家', '国籍'],
#  ['凯利MagooDossenback', '海军将领', '美国', '国家', '国籍'],
#  ['亚当“吉利根”布莱恩', '海军将领', '美国', '国家', '国籍'],
#  ['迪尔德丽·A·帕克', '海军将领', '美国', '国家', '国籍'],
#  ['布拉德福德J.GERING', '海军将领', '美国', '国家', '国籍'],
#  ['布罗迪', '海军将领', '美国', '国家', '国籍'],
#  ['埃里克·加西亚', '海军将领', '美国', '国家', '国籍'],
#  ['雅各布·弗巴斯', '海军将领', '美国', '国家', '国籍'],
#  ['凯文·琼斯', '海军将领', '美国', '国家', '国籍'],
#  ['莫里斯', '海军将领', '美国', '国家', '国籍'],
#  ['克里斯托弗·K·怀特豪斯', '海军将领', '美国', '国家', '国籍'],
#  ['梅森·W·贝瑞', '海军将领', '美国', '国家', '国籍'],
#  ['内森·希基', '海军将领', '美国', '国家', '国籍'],
#  ['贾米尔“Faceman”麦克丹尼尔', '海军将领', '美国', '国家', '国籍'],
#  ['斯科特“王牌”利平科特', '海军将领', '美国', '国家', '国籍'],
#  ['大卫·J·塞奎拉', '海军将领', '美国', '国家', '国籍'],
#  ['杰西卡·E·考德威尔', '海军将领', '美国', '国家', '国籍'],
#  ['詹姆斯·J·莱特', '海军将领', '美国', '国家', '国籍'],
#  ['吉内恩·狄更斯', '海军将领', '美国', '国家', '国籍'],
#  ['第116航母机载预警中队', '作战中队', '约瑟夫·詹姆斯', '海军将领', '指挥军士长'],
#  ['第116航母机载预警中队', '作战中队', '约翰·加勒特·巴里', '海军将领', '指挥官'],
#  ['第116航母机载预警中队', '作战中队', 'RJ菲尔兹', '海军将领', '执行官'],
#  ['约瑟夫·詹姆斯', '海军将领', 'unknown', '州', '家庭信息'],
#  ['约翰·加勒特·巴里', '海军将领', 'unknown', '州', '家庭信息'],
#  ['RJ菲尔兹', '海军将领', 'unknown', '州', '家庭信息'],
#  ['约瑟夫·詹姆斯', '海军将领', '美国', '国家', '国籍'],
#  ['约翰·加勒特·巴里', '海军将领', '美国', '国家', '国籍'],
#  ['RJ菲尔兹', '海军将领', '美国', '国家', '国籍'],
#  ['约瑟夫·詹姆斯', '海军将领', '约翰·加勒特·巴里', '海军将领', '同事'],
#  ['约瑟夫·詹姆斯', '海军将领', 'RJ菲尔兹', '海军将领', '同事'],
#  ['约翰·加勒特·巴里', '海军将领', '约瑟夫·詹姆斯', '海军将领', '同事'],
#  ['约翰·加勒特·巴里', '海军将领', 'RJ菲尔兹', '海军将领', '同事'],
#  ['RJ菲尔兹', '海军将领', '约瑟夫·詹姆斯', '海军将领', '同事'],
#  ['RJ菲尔兹', '海军将领', '约翰·加勒特·巴里', '海军将领', '同事']]

# %% [markdown]
# #### 9 构建“十一打击群”图谱（包含规则生成的五元组）
# “十一打击群”五元组数据

# %%
import pandas as pd
from tqdm import tqdm
def link_completion():
    res_tuples = list()
    state_set = set()
    df = pd.read_excel('E:/neo4j/triples_10_16.xlsx')
    triples = df.values.tolist()
    new_triples = []
    for triple in triples:
        new_triple = []
        for str in triple:
            str = ''.join(str.split()) # 去掉空格字符
            new_triple.append(str)
        new_triples.append(new_triple)
    for tup in new_triples:
        h, h_typ, t, t_typ, r = tup
        if (h_typ, r, t_typ) == ('海军将领', '家庭信息', '州'):
            res_tuples.append((h, h_typ,  '美国', '国家', '国籍'))
        if h_typ == '州':
            state_set.add(h)
        if t_typ == '州':
            state_set.add(t)
    for state in list(state_set):
          res_tuples.append((state, '州',  '美国', '国家', '隶属'))
    return new_triples + res_tuples
new_triples = link_completion()
for triple in tqdm(new_triples):
    head, head_typ, tail, tail_typ, rel = triple # 取出头实体、尾实体、关系
    head_node = Node(head_typ, name=head)
    tail_node = Node(tail_typ, name=tail)
    graph.merge(head_node, head_typ, "name")
    graph.merge(tail_node, tail_typ, "name")                  
    graph.create(Relationship(head_node, rel, tail_node))
# Out:
# 100%|██████████| 447/447 [00:08<00:00, 51.91it/s]

# %% [markdown]
# #### 10 构建“装备知识图谱”图谱

# %%
from tqdm import tqdm
openkg = load_pickle_file('equipment_kg.pkl')
res = []
for triple in tqdm(openkg):
    h, h_t,r, t, t_t,  = triple # 取出头实体、尾实体、关系
    node1 = Node(h_t, name=h)
    node2 = Node(t_t, name=t)
    graph.merge(node1, h_t, "name")
    graph.merge(node2, t_t, "name")
    graph.create(Relationship(node1, rel, node2))
openkg
# Out:
# 100%|██████████| 8281/8281 [01:03<00:00, 129.79it/s]
# [('歼-16战机', '战斗机', '产国', '中国', '国家'),
#  ('歼-16战机', '战斗机', '研发单位', '中国沈阳飞机公司', '研发单位'),
#  ('FC-1“枭龙”/JF-17“雷电”多用途攻击机', '战斗机', '产国', '中国', '国家'),
#  ('FC-1“枭龙”/JF-17“雷电”多用途攻击机', '战斗机', '研发单位', '成都飞机公司', '研发单位'),
#  ('苏-27战斗机', '战斗机', '产国', '苏/俄', '国家'),
#  ('苏-27战斗机', '战斗机', '研发单位', '苏霍伊设计局', '研发单位'),
#  ('LCA战斗机', '战斗机', '产国', '印度', '国家'),
#  ('LCA战斗机', '战斗机', '研发单位', '印度HAL公司', '研发单位'),
#  ('苏-30/苏-33“侧卫” 制空战斗机和对地攻击机', '战斗机', '产国', '苏/俄', '国家'),
#  ('苏-30/苏-33“侧卫” 制空战斗机和对地攻击机', '战斗机', '研发单位', '苏霍伊设计局', '研发单位'),
#  ('F-16“战隼”', '战斗机', '产国', '美国', '国家'),
#  ('F-16“战隼”', '战斗机', '研发单位', '通用动力公司', '研发单位'),
#  ('麦克唐纳F-15E“打击鹰” 双座双发打击战斗机', '战斗机', '产国', '美国', '国家'),
#  ('麦克唐纳F-15E“打击鹰” 双座双发打击战斗机', '战斗机', '研发单位', '麦克唐纳-道格拉斯公司', '研发单位'),
#  ('歼-31战斗机', '战斗机', '产国', '中国', '国家'),
#  ('歼-31战斗机', '战斗机', '研发单位', '沈阳飞机公司', '研发单位'),
#  ('F-15鹰式战斗机', '战斗机', '产国', '美国', '国家'),
#  ('F-15鹰式战斗机', '战斗机', '研发单位', '美国波音公司', '研发单位'),
#  ('F-16“战隼”', '战斗机', '产国', '中国', '国家'),
#  ('F-16“战隼”', '战斗机', '研发单位', '成都飞机工业集团', '研发单位'),
#  ('F-35“闪电II”', '战斗机', '产国', '美国', '国家'),
#  ('F-35“闪电II”', '战斗机', '研发单位', '美国洛克希德·马丁公司', '研发单位'),
#  ('歼-11战斗机', '战斗机', '产国', '中国', '国家'),
#  ('P-59“空中彗星”战斗机', '战斗机', '产国', '美国', '国家'),
#  
#  ('A-10“雷电II”', '攻击机', '研发单位', '美国仙童公司', '研发单位'),
#  ('OV-10“野马” 空中前进控制机/近距离空中支援机', '攻击机', '产国', '美国', '国家'),
#  ('OV-10“野马” 空中前进控制机/近距离空中支援机', '攻击机', '研发单位', '北美公司', '研发单位'),
#  ('A-5/RA-5“民团团员” 轰炸机/侦察机', '攻击机', '产国', '美国', '国家'),
#  ('AD/A-1“空中袭击者”', '攻击机', '产国', '美国', '国家'),
#  ('沃特(N-G)A-7“海盗Ⅱ”', '攻击机', '产国', '美国', '国家'),
#  ('沃特(N-G)A-7“海盗Ⅱ”', '攻击机', '研发单位', '凌·特姆科·沃特公司', '研发单位'),
#  ('AM“拳师”攻击机', '攻击机', '产国', '美国', '国家'),
#  ('AM“拳师”攻击机', '攻击机', '研发单位', '格伦·马丁公司', '研发单位'),
#  ('A-6“入侵者”攻击机', '攻击机', '产国', '美国', '国家'),
#  ('A-6“入侵者”攻击机', '攻击机', '研发单位', '格鲁曼公司', '研发单位'),
#  ('超级军旗攻击机', '攻击机', '产国', '法国', '国家'),
#  ('超级军旗攻击机', '攻击机', '研发单位', '法国达索公司', '研发单位'),
#  ('英国航宇 FRS.51喷气式战斗攻击机', '攻击机', '产国', '英国', '国家'),
#  ('英国航宇 FRS.51喷气式战斗攻击机', '攻击机', '研发单位', '英国宇航公司', '研发单位'),
#  ('AU-24“公马”攻击机', '攻击机', '产国', '美国', '国家'),
#  ('13式舰上攻击机', '攻击机', '产国', '日本', '国家'),
#  ('13式舰上攻击机', '攻击机', '研发单位', '三菱重工', '研发单位'),
#  ('神龙特殊攻击机', '攻击机', '产国', '日本', '国家'),
#  ('神龙特殊攻击机', '攻击机', '研发单位', '“美津浓”公司', '研发单位'),
#  ('Hs 129攻击机', '攻击机', '产国', '德国', '国家'),
#  ('Hs 129攻击机', '攻击机', '研发单位', '亨舍尔公司', '研发单位'),
#  (' B5N/97式1号舰上攻击机', '攻击机', '产国', '日本', '国家'),
#  (' B5N/97式1号舰上攻击机', '攻击机', '研发单位', '中岛公司', '研发单位'),
#  ('Ki-115甲剑特殊攻击机', '攻击机', '产国', '日本', '国家'),
#  ('Ki-115甲剑特殊攻击机', '攻击机', '研发单位', '中岛', '研发单位'),
#  ('M6A1 晴岚攻击机', '攻击机', '产国', '日本', '国家'),
#  ('M6A1 晴岚攻击机', '攻击机', '研发单位', '日本爱知飞机制造公司', '研发单位'),
#  ('AT-3高级教练/轻攻击机', '攻击机', '产国', '中国', '国家'),
#  ('AT-3高级教练/轻攻击机', '攻击机', '研发单位', '汉翔工业', '研发单位'),
#  ('B5M/97式2号舰上攻击机', '攻击机', '产国', '日本', '国家'),
#  ('B5M/97式2号舰上攻击机', '攻击机', '研发单位', '三菱重工', '研发单位'),
#  ('A-17/A-33', '攻击机', '产国', '美国', '国家'),
#  ('G4M/一式陆上攻击机', '攻击机', '产国', '日本', '国家'),
#  ('B7A流星舰上攻击机', '攻击机', '产国', '日本', '国家'),
#  ('夕号试作特殊攻击机', '攻击机', '产国', '日本', '国家'),
�炸机', '轰炸机', '产国', '美国', '国家'),
#  ('F8F“熊猫”战斗轰炸机', '轰炸机', '研发单位', '美国格鲁曼公司', '研发单位'),
#  ('SBD“无畏式”', '轰炸机', '产国', '美国', '国家'),
#  ('图-160“海盗旗” 远程轰炸机', '轰炸机', '产国', '苏/俄', '国家'),
#  ('图-160“海盗旗” 远程轰炸机', '轰炸机', '研发单位', '图波列夫设计局', '研发单位'),
#  ('“堪培拉” 轰炸机/入侵飞机/侦察机', '轰炸机', '产国', '英国', '国家'),
#  ('“堪培拉” 轰炸机/入侵飞机/侦察机', '轰炸机', '研发单位', '英国电气公司（英国航宇公司）', '研发单位'),
#  ('PB4Y-2“私掠船”', '轰炸机', '产国', '美国', '国家'),
#  ('PB4Y-2“私掠船”', '轰炸机', '研发单位', '联合公司', '研发单位'),
#  ('B-32“统治者”', '轰炸机', '产国', '美国', '国家'),
#  ('B-32“统治者”', '轰炸机', '研发单位', '美国联合公司', '研发单位'),
#  ('F/FB/EF-111战斗轰炸机', '轰炸机', '产国', '美国', '国家'),
#  ('F/FB/EF-111战斗轰炸机', '轰炸机', '研发单位', '美国通用动力公司', '研发单位'),
#  ('B-45“龙卷风”', '轰炸机', '产国', '美国', '国家'),
#  ('B-45“龙卷风”', '轰炸机', '研发单位', '北美航空公司', '研发单位'),
#  ('B-57“堪培拉”', '轰炸机', '产国', '美国', '国家'),
#  ('B-2“幽灵” 战略轰炸机', '轰炸机', '产国', '美国', '国家'),
#  ('SB2C“地狱俯冲者”', '轰炸机', '产国', '美国', '国家'),
#  ('B-24“解放者”', '轰炸机', '产国', '美国', '国家'),
#  ('B-24“解放者”', '轰炸机', '研发单位', '联合公司（United Aircraft Corporation） ', '研发单位'),
#  ('B-26/JM“劫掠者”', '轰炸机', '产国', '美国', '国家'),
#  ('B-26/JM“劫掠者”', '轰炸机', '研发单位', '马丁公司', '研发单位'),
#  ('B/KB-50“超级堡垒”', '轰炸机', '产国', '美国', '国家'),
#  ('B/KB-50“超级堡垒”', '轰炸机', '研发单位', '波音公司', '研发单位'),
#  ('TBF/TBM“复仇者”', '轰炸机', '产国', '美国', '国家'),
#  ('BTD “毁灭者”', '轰炸机', '产国', '美国', '国家'),
#  ('PBM“水手”', '轰炸机', '产国', '美国', '国家'),
#  ('PBM“水手”', '轰炸机', '研发单位', '马丁公司', '研发单位'),
#  ('B-34/37和PV“文图拉”/“捕鲸叉” ', '轰炸机', '产国', '美国', '国家'),
#  ('B-34/37和PV“文图拉”/“捕鲸叉” ', '轰炸机', '研发单位', '洛克希德公司', '研发单位'),
#  ('A/B-26/JD“入侵者”', '轰炸机', '产国', '美国', '国家'),
#  ('B-25/PBJ“米切尔”', '轰炸机', '产国', '美国', '国家'),
#  ('B-25/PBJ“米切尔”', '轰炸机', '研发单位', '北美航空公司', '研发单位'),
#  ('B-1B“枪骑兵”', '轰炸机', '产国', '美国', '国家'),
#  ('B-1B“枪骑兵”', '轰炸机', '研发单位', '美国罗克韦尔公司', '研发单位'),
#  ('A-20“浩劫”', '轰炸机', '产国', '美国', '国家'),
#  ('SBU', '轰炸机', '产国', '美国', '国家'),
练机', '教练机', '产国', '苏/俄', '国家'),
#  ('米格-AT 高级教练机', '教练机', '研发单位', '俄罗斯米格飞机公司 ', '研发单位'),
#  ('T-38“禽爪” 高级教练机', '教练机', '产国', '美国', '国家'),
#  ('T-6A“德克萨斯人II”', '教练机', '产国', '美国', '国家'),
#  ('T-6A“德克萨斯人II”', '教练机', '研发单位', '美国比奇公司（现在是雷声公司的子公司）', '研发单位'),
#  ('AT-8/17/UC-78“短尾猫”', '教练机', '产国', '美国', '国家'),
#  ('AT-8/17/UC-78“短尾猫”', '教练机', '研发单位', '塞斯纳公司', '研发单位'),
#  ('T-47/UC-35“奖状”', '教练机', '产国', '美国', '国家'),
#  ('T-47/UC-35“奖状”', '教练机', '研发单位', '塞斯纳公司', '研发单位'),
#  ('T-41“梅斯卡勒罗人”', '教练机', '产国', '美国', '国家'),
#  ('A-8/PQ-8/TOC-2', '教练机', '产国', '美国', '国家'),
#  ('A-8/PQ-8/TOC-2', '教练机', '研发单位', '卡尔弗公司', '研发单位'),
#  ('AT-21“机枪手”', '教练机', '产国', '美国', '国家'),
#  ('BC/AT-6/SNJ“德克萨斯人”', '教练机', '产国', '美国', '国家'),
#  ('BC/AT-6/SNJ“德克萨斯人”', '教练机', '研发单位', '北美航空公司', '研发单位'),
#  ('T-39 “佩刀客”', '教练机', '产国', '美国', '国家'),
#  ('T-39 “佩刀客”', '教练机', '研发单位', '北美公司', '研发单位'),
#  ('T-2“橡树” 教练机', '教练机', '产国', '美国', '国家'),
#  ('AT-9', '教练机', '产国', '美国', '国家'),
#  ('AT-9', '教练机', '研发单位', '寇蒂斯公司', '研发单位'),
#  ('PQ-14/TD2C-1', '教练机', '产国', '美国', '国家'),
#  ('PQ-14/TD2C-1', '教练机', '研发单位', '卡尔弗公司', '研发单位'),
#  ('PT-16/20/21/22和NR-1“补充兵”', '教练机', '产国', '美国', '国家'),
#  ('PT-16/20/21/22和NR-1“补充兵”', '教练机', '研发单位', '美国瑞安（Ryan）航空公司', '研发单位'),
#  ('T/CT-43和T-40“快船”', '教练机', '产国', '美国', '国家'),
#  ('T/CT-43和T-40“快船”', '教练机', '研发单位', '波音公司', '研发单位'),
#  ('沃多霍迪L-39/L-139/L-59/L-159高级喷气教练机和轻型攻击机', '教练机', '产国', '捷克', '国家'),
#  ('沃多霍迪L-39/L-139/L-59/L-159高级喷气教练机和轻型攻击机', '教练机', '研发单位', '捷克沃多霍迪航空', '研发单位'),
#  ('N2T“导师”', '教练机', '产国', '美国', '国家'),
#  ('N2T“导师”', '教练机', '研发单位', '美国蒂姆飞机公司', '研发单位'),
#  ('海军飞机制造厂N3N ', '教练机', '产国', '美国', '国家'),
#  ('海军飞机制造厂N3N ', '教练机', '研发单位', '美国海军飞机制造厂', '研发单位'),
#  ('PT-19/23/26“康奈尔”', '教练机', '产国', '美国', '国家'),
#  ('PT-19/23/26“康奈尔”', '教练机', '研发单位', '仙童公司', '研发单位'),
#  ('BT-9/14和NJ-1', '教练机', '产国', '美国', '国家'),
#  ('T-37“鸣叫”和A/QA-37“龙蝇” ', '教练机', '产国', '美国', '国家'),
#  ('MAKO教练机', '教练机', '产国', '德国', '国家'),
#  ('萨博MFI-17/支持者轻型教练机/观测飞机', '教练机', '产国', '瑞典', '国家'),
#  ('MB-339高级教练机/轻型攻击机', '教练机', '产国', '意大利', '国家'),
#  ('MB-339高级教练机/轻型攻击机', '教练机', '研发单位', '意大利马基公司', '研发单位'),
#  ('三菱T-2高级喷气教练机', '教练机', '产国', '日本', '国家'),
#  ('IAR-99“鹰”高级喷气教练机/轻型攻击机', '教练机', '产国', '罗马尼亚', '国家'),
#  ('马基（SIAI-马歇蒂）SF.260特技飞行与武器教练机', '教练机', '产国', '意大利', '国家'),
#  ('马基（SIAI-马歇蒂）SF.260特技飞行与武器教练机', '教练机', '研发单位', '意大利马基公司', '研发单位'),
#  ('雅克-11中级教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-11中级教练机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('“虎蛾”式教练机', '教练机', '产国', '英国', '国家'),
#  ('“虎蛾”式教练机', '教练机', '研发单位', '德哈维兰公司', '研发单位'),
#  ('雅克-53特技教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-53特技教练机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('鹰(HAWK)式教练机  ', '教练机', '产国', '英国', '国家'),
#  ('鹰(HAWK)式教练机  ', '教练机', '研发单位', '英国航宇公司(霍克·西德利公司)', '研发单位'),
#  ('CM-170轻型教练/攻击机', '教练机', '产国', '法国', '国家'),
#  ('CM-170轻型教练/攻击机', '教练机', '研发单位', '法国宇航公司', '研发单位'),
#  ('雅克-32教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-32教练机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('UT-2教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('UT-2教练机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('雅克-30 截击机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-30 截击机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('UT-1教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('UT-1教练机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('雅克-52初级教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-52初级教练机', '教练机', '研发单位', '雅科夫列夫实验设计局', '研发单位'),
#  ('S-312巨嘴鸟(Tucano)教练机', '教练机', '产国', '英国', '国家'),
#  ('S-312巨嘴鸟(Tucano)教练机', '教练机', '研发单位', '肖特兄弟公司', '研发单位'),
#  ('雅克-50特技级飞机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-50特技级飞机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('雅克-200教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-200教练机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('雅克-18教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-210教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-210教练机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('雅克-54教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-54教练机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('CM.170教师双座双发喷气教练机', '教练机', '产国', '法国', '国家'),
#  ('CM.170教师双座双发喷气教练机', '教练机', '研发单位', '法国原富加公司(现已并入法国国营航宇工业公司)', '研发单位'),
#  ('雅克-55教练机', '教练机', '产国', '苏/俄', '国家'),
#  ('雅克-55教练机', '教练机', '研发单位', '雅科夫列夫设计局', '研发单位'),
#  ('E-2鹰眼预警机', '预警机', '产国', '美国', '国家'),
#  ('E-2鹰眼预警机', '预警机', '研发单位', '格鲁门飞机公司', '研发单位'),
#  ('运-8J海上警戒机', '预警机', '产国', '中国', '国家'),
#  ('运-8J海上警戒机', '预警机', '研发单位', '陕西飞机工业（集团）有限公司', '研发单位'),
#  ...]

# %% [markdown]
# #### 11 将数据插入数据库

# %%
# 导入python插入数据到数据库的函数
from pyMysql import mysql_query, mysql_in_up_re
from linkPrediction2Mysql import get_time

# %%
status = '未入库'
source = '十一打击群'
sql = 'insert into candidate_triples(head, head_category, relation, tail, tail_category, status, time, source) values(%s, %s, %s, %s, %s, %s, %s, %s)'
mysql_in_up_re(sql, (head, head_typ, rel, tail, tail_typ, status, get_time(), source))
